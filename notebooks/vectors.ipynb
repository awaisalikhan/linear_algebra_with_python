# %%
[10.0, 5.0, 10, 5]
# Out:
# [10.0, 5.0, 10, 5]

# %%
import numpy as np

# %%
video = np.array([10.5, 5.2, 3.25, 7.0])

# %%
video
# Out:
# array([10.5 ,  5.2 ,  3.25,  7.  ])

# %%
video.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 video.size()
#
# TypeError: 'int' object is not callable

# %%
video.size
# Out:
# 4

# %%
video[-1]
# Out:
# np.float64(7.0)

# %%
video[0] = 2

# %%
video
# Out:
# array([2.  , 5.2 , 3.25, 7.  ])

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
u = np.array([2,5])
v = np.array([3, 6])

# %%
scatter_x, scatter_y = zip(u,v)

# %%
scatter_x
# Out:
# (np.int64(2), np.int64(3))

# %%
plt.scatter(scatter_x,scatter_y,color=["r","b"])
plt.grid()
plt.axis([0,9, 0, 9])
plt.show()

# %%
plt.arrow()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plt.arrow()
#
# TypeError: arrow() missing 4 required positional arguments: 'x', 'y', 'dx', and 'dy'

# %%
plt.arrow(0,0, scatter_x[0],scatter_y[1],head_width=0.2, head_length=0.3, length_includes_head=True)

# %%
def plt_vector2d( vector2d,origin = [0, 0], **options):
    return plt.arrow(origin[0], origin[1], vector2d[0], vector2d[1],head_width=0.2, head_length=0.3, length_includes_head=True, **options)

# %%
plat.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 plat.grid()
#
# NameError: name 'plat' is not defined

# %%
plt_vector2d(u,color='r')
plt_vector2d(v,color='g')
plt.grid()
plt.axis([0, 9, 0, 9])
plt.show()

# %%
a = np.array([3, 5, 8])
b = np.array([2, 4, 8])

# %%
subplot3d = plt.subplot(111, projection='3d')
x_coords, y_coords, z_coords = zip(a,b)
subplot3d.scatter(x_coords, y_coords, z_coords)
subplot3d.set_zlim3d([0, 9])
plt.show()
